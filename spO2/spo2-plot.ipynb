# %%
import numpy as np
import matplotlib.pyplot as plt
# make plots bigger
plt.rcParams['figure.figsize'] = (16., 8)

# %%
spo2=np.loadtxt('nap.csv', delimiter=',', skiprows=1)
maxtime = np.max(spo2[:,0])
print("{} seconds of pulse data loaded".format(maxtime))
# Out:
# 3212.0 seconds of pulse data loaded

# %%
def plot_spo2(time, pulse, spo2):

    fig, ax1 = plt.subplots()

    color = 'tab:red'
    ax1.set_xlabel('time (s)')
    ax1.set_ylabel('spO2', color=color)
    ax1.plot(time,spo2,label='spO2',color=color)
    ax1.tick_params(axis='y', labelcolor=color)
    ax1.set_ylim(85,100)
    
    ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

    color = 'tab:blue'
    ax2.set_ylabel('Pulse', color=color)  # we already handled the x-label with ax1
    ax2.plot(time, pulse, color=color)
    ax2.tick_params(axis='y', labelcolor=color)
    ax2.set_xlabel('Time (sec)')
    ax2.set_ylim(30,120)
    plt.legend()
    
plot_spo2(spo2[:,0],spo2[:,3],spo2[:,2])
# Out:
# No handles with labels found to put in legend.

# %%
t=range(350,500)
plt.plot(spo2[600:700,3],label='pulse')
plt.plot(spo2[600:700,3],'x',label='pulsec')
plt.plot(spo2[600:700,1],'x',label='pulsec')
#plt.plot(spo2[t,3],label='spO2')

# %%
spo2=np.loadtxt('ct127.csv', delimiter=',', skiprows=1)
maxtime = np.max(spo2[:,0])
print("{} seconds of pulse data loaded".format(maxtime))
# Out:
# 1886.0 seconds of pulse data loaded

# %%
plt.plot(spo2[:,2],label='pulse')
plt.plot(spo2[:,3],label='spO2')
plt.plot(spo2[:,1],label='flags')

# %%
t=range(350,500)
plt.plot(spo2[1000:1150,3],label='pulse')
plt.plot(spo2[1090:1150,3],'x',label='pulsec')
plt.plot(spo2[1000:1150,1],'x',label='pulsec')
#plt.plot(spo2[t,3],label='spO2')

# %%
spo2=np.loadtxt('run2.csv', delimiter=',', skiprows=1)
maxtime = np.max(spo2[:,0])
print("{} seconds of pulse data loaded".format(maxtime))
# Out:
# 2369.0 seconds of pulse data loaded

# %%
plt.plot(spo2[10:2200,2],label='pulse')
plt.plot(spo2[10:2200,3],label='spO2')
#plt.plot(spo2[:,1],label='flags')
